# %%
import pandas as pd

from aidream_registration import constants
from aidream_registration.dataloaders import AtlasImagingNiftiLoader
from aidream_registration.utils.cohort_utils import get_perfusion_patients
from sklearn.utils import resample

from torch.optim.lr_scheduler import ReduceLROnPlateau

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, Dataset
from sklearn.model_selection import train_test_split


import numpy as np
import ants
import rt_utils

# %%
torch.cuda.empty_cache()

# %%
list_patients = get_perfusion_patients()
print("Number of patients:", len(list_patients))
# Out:
# Number of patients: 186

# %%
# Load the atlas imaging nifti loader :
atlas_loader = AtlasImagingNiftiLoader(source_mri="PIPELINE_SS")

# %%
# First, load the hammersmith atlas, and create a mask :
path_hammersmith = constants.DIR_DATA / "hammersmith" / "T1w_ICBM_skullstripped.nii.gz"
ants_hammersmith = ants.image_read(str(path_hammersmith))

mask_hammersmith = ants_hammersmith > 0
print(f"Hammersmith mask volume: {mask_hammersmith.sum() / 1e3:.2f} cm3")
# Out:
# Hammersmith mask volume: 1886.57 cm3

# %%
# Load all segmentations in a dictionary :
dict_segmentations = {
    path_seg.name.removesuffix(".nii.gz"): ants.image_read(str(path_seg)) > 0
    for path_seg in (constants.DIR_DATA / "hammersmith").glob("*.nii.gz")
    if path_seg.name != "T1w_ICBM_skullstripped.nii.gz"
}

print("Number of segmentations:", len(dict_segmentations))

for segmentation, mask_segmentation in dict_segmentations.items():
    print(fr"{segmentation} volume: {mask_segmentation.sum() / 1e3:.2f} cm3")
# Out:
# Number of segmentations: 21
# L.Ventricles volume: 6.72 cm3
# R_insula volume: 16.48 cm3
# R.Ventricles volume: 6.11 cm3
# L.Temporal_lobe volume: 115.72 cm3
# R.Occipital_lobe volume: 76.46 cm3
# L.Grey_nuclei volume: 18.22 cm3
# R.Grey_nuclei volume: 18.20 cm3
# R.Limbic_lobe volume: 24.28 cm3
# Brainstem volume: 26.94 cm3
# L.frontal_lobe volume: 225.46 cm3
# third_ventricle volume: 0.63 cm3
# L.Post_fossea volume: 90.63 cm3
# L.Parietal_lobe volume: 142.35 cm3
# Corpus_callosum volume: 21.05 cm3
# R.Temporal_lobe volume: 121.76 cm3
# L.Occipital_lobe volume: 75.31 cm3
# R.frontal_lobe volume: 227.50 cm3
# R.Post_fossea volume: 88.57 cm3
# R.Parietal_lobe volume: 141.59 cm3
# L.Limbic_lobe volume: 24.96 cm3
# L_insula volume: 16.62 cm3

# %%
# Create mask_1 for the ventricle voxels :
mask_1 = dict_segmentations["L.Ventricles"] + dict_segmentations["R.Ventricles"] + dict_segmentations["third_ventricle"]
mask_1 = mask_1 > 0

print(f"Ventricles volume: {mask_1.sum() / 1e3:.2f} cm3")
# Out:
# Ventricles volume: 13.47 cm3

# %%
# Create mask82 for the segmented voxels that are not ventricles :
mask_2 = None
for seg, mask_segmentation in dict_segmentations.items():

    if seg not in ["L.Ventricles", "R.Ventricles", "third_ventricle"]:
        if mask_2 is None:
            mask_2 = mask_segmentation
        else:
            mask_2 += mask_segmentation

mask_2 = mask_2 > 0

print(f"Brain volume: {mask_2.sum() / 1e3:.2f} cm3")

mask_2.to_file(str(constants.DIR_DATA / "hammersmith" / "custom" / "mask_2.nii.gz"))
# Out:
# Brain volume: 1472.11 cm3

# %%
# Create mask_unknown for the voxels that are not segmented :
mask_unknown = mask_hammersmith * (1 - mask_1) * (1 - mask_2)
mask_unknown = mask_unknown > 0

print(f"Unknown volume: {mask_unknown.sum() / 1e3:.2f} cm3")

mask_unknown.to_file(str(constants.DIR_DATA / "hammersmith" / "custom" / "unknown.nii.gz"))
# Out:
# Unknown volume: 405.38 cm3

# %%
# Create two bounding boxes for the ventricles , a small one and a big one :

seg_idx = np.array(np.nonzero(mask_1.numpy()))

bbox_min, bbox_max = np.min(seg_idx, axis=1), np.max(seg_idx, axis=1)

bbox_min_1, bbox_max_1 = bbox_min - 3, bbox_max + 3
bbox_min_2, bbox_max_2 = bbox_min - 8, bbox_max + 8

np_bbox_1 = np.zeros(mask_1.shape)
np_bbox_1[bbox_min_1[0]: bbox_max_1[0], bbox_min_1[1]: bbox_max_1[1], bbox_min_1[2]: bbox_max_1[2]] = 1

np_bbox_2 = np.zeros(mask_1.shape)
np_bbox_2[bbox_min_2[0]: bbox_max_2[0], bbox_min_2[1]: bbox_max_2[1], bbox_min_2[2]: bbox_max_2[2]] = 1

mask_small = (ants.from_numpy(np_bbox_1, origin=mask_1.origin, spacing=mask_1.spacing, direction=mask_1.direction) > 0) * mask_hammersmith
mask_big = (ants.from_numpy(np_bbox_2, origin=mask_1.origin, spacing=mask_1.spacing, direction=mask_1.direction) > 0) * mask_hammersmith

# %%
# all voxels inside mask_small that are also in mask_unknown are to be predicted :
mask_pred = mask_small * mask_unknown

print(f"Prediction volume: {mask_pred.sum() / 1e3:.2f} cm3")

# all voxels inside mask_big and not in mask_small that are also in mask_unknown are csf voxels :
mask_csf = mask_big * (1 - mask_small) * mask_unknown

print(f"CSF volume: {mask_csf.sum() / 1e3:.2f} cm3")

# for brain voxels, keep only the voxels that are in mask_big :
mask_2 = mask_2 * mask_big

print(f"new Brain volume: {mask_2.sum() / 1e3:.2f} cm3")
# Out:
# Prediction volume: 152.20 cm3
# CSF volume: 34.17 cm3
# new Brain volume: 460.25 cm3

# %%
mask_4 = mask_2 + mask_csf
mask_4 = mask_4 > 0

# %%
# Generate spatial coordinate images :
x,y,z = ants_hammersmith.shape

x_coords = np.linspace(0, 1, x)[:, None, None]
y_coords = np.linspace(0, 1, y)[None, :, None]
z_coords = np.linspace(0, 1, z)[None, None, :]

x_map = np.broadcast_to(x_coords, (x, y, z))
y_map = np.broadcast_to(y_coords, (x, y, z))
z_map = np.broadcast_to(z_coords, (x, y, z))

ants_x_map = ants.from_numpy(x_map, origin=ants_hammersmith.origin, spacing=ants_hammersmith.spacing, direction=ants_hammersmith.direction)
ants_y_map = ants.from_numpy(y_map, origin=ants_hammersmith.origin, spacing=ants_hammersmith.spacing, direction=ants_hammersmith.direction)
ants_z_map = ants.from_numpy(z_map, origin=ants_hammersmith.origin, spacing=ants_hammersmith.spacing, direction=ants_hammersmith.direction)

# %%
mask_1.to_file(str(constants.DIR_DATA / "hammersmith" / "custom" / "ventricles.nii.gz"))
mask_2.to_file(str(constants.DIR_DATA / "hammersmith" / "custom" / "brain.nii.gz"))
mask_csf.to_file(str(constants.DIR_DATA / "hammersmith" / "custom" / "csf.nii.gz"))
mask_pred.to_file(str(constants.DIR_DATA / "hammersmith" / "custom" / "prediction.nii.gz"))

# %%
# Now, let's treat the problem as a Machine Learning classification problem :
# The training data will be mask_1 and mask_2 and mask_csf :

# First, create the training data :
# add mask_1 :
ventricles_idx = np.array(np.nonzero(mask_1.numpy()))
ventricles_intensity = ants_hammersmith.numpy()[ventricles_idx[0], ventricles_idx[1], ventricles_idx[2]]
df_ventricles = pd.DataFrame({"x": ventricles_idx[0], "y": ventricles_idx[1], "z": ventricles_idx[2], "intensity": ventricles_intensity, "label": 0})

# # now add mask_2 :
# brain_idx = np.array(np.nonzero(mask_2.numpy()))
# brain_intensity = ants_hammersmith.numpy()[brain_idx[0], brain_idx[1], brain_idx[2]]
# df_brain = pd.DataFrame({"x": brain_idx[0], "y": brain_idx[1], "z": brain_idx[2], "intensity": brain_intensity, "label": 1})
#
# # now add mask_csf :
# csf_idx = np.array(np.nonzero(mask_csf.numpy()))
# csf_intensity = ants_hammersmith.numpy()[csf_idx[0], csf_idx[1], csf_idx[2]]
# df_csf = pd.DataFrame({"x": csf_idx[0], "y": csf_idx[1], "z": csf_idx[2], "intensity": csf_intensity, "label": 2})

# mask_4 :
brain_idx = np.array(np.nonzero(mask_4.numpy()))
brain_intensity = ants_hammersmith.numpy()[brain_idx[0], brain_idx[1], brain_idx[2]]
df_brain = pd.DataFrame({"x": brain_idx[0], "y": brain_idx[1], "z": brain_idx[2], "intensity": brain_intensity, "label": 1})


# Concatenate the dataframes :
# df_train = pd.concat([df_ventricles, df_brain, df_csf], ignore_index=True)
df_train = pd.concat([df_ventricles, df_brain], ignore_index=True)

print(fr"len(df_train): {len(df_train)}")

X_train, y_train = df_train[["x", "y", "z", "intensity"]].values, df_train["label"].values

print(f"Number of training samples: {len(X_train)}")
print(f"percentage of ventricles in the training set: {np.mean(y_train == 0):.4f}")
print(f"percentage of brain in the training set: {np.mean(y_train == 1):.4f}")
# print(f"percentage of CSF in the training set: {np.mean(y_train == 2):.2f}")
# Out:
# len(df_train): 507885
# Number of training samples: 507885
# percentage of ventricles in the training set: 0.0265
# percentage of brain in the training set: 0.9735

# %%
# # Let's resample the training data to balance the classes :
ventricles = df_train[df_train["label"] == 0]
brain = df_train[df_train["label"] == 1]

# # the desired distribution is 1:1
desired_ventricles_size  = int(len(df_train) * 0.5)
desired_brain_size = len(df_train) - desired_ventricles_size
#
# # Oversampling the ventricles  :
ventricles_resampled = resample(ventricles, n_samples=desired_ventricles_size, replace=True, random_state=42)
# csf_resampled = resample(csf, n_samples=desired_csf_size, replace=True, random_state=42)
#
# # Downsampling the brain :
brain_resampled = resample(brain, n_samples=desired_brain_size, replace=False, random_state=42)
#
# # Concatenate the resampled dataframes :
df_train_resampled = pd.concat([ventricles_resampled, brain_resampled], ignore_index=True)
#
X_train, y_train = df_train_resampled[["x", "y", "z", "intensity"]].values, df_train_resampled["label"].values
#
# print(f"Number of training samples: {len(X_train)}")
# print(f"Number of validation samples: {len(X_val)}")
#
# print(f"percentage of ventricles in the training set: {np.mean(y_train == 0):.2f}, and in the validation set: {np.mean(y_val == 0):.2f}")
# print(f"percentage of CSF in the training set: {np.mean(y_train == 1):.2f}, and in the validation set: {np.mean(y_val == 1):.2f}")
# print(f"percentage of brain in the training set: {np.mean(y_train == 2):.2f}, and in the validation set: {np.mean(y_val == 2):.2f}")

# %%
# Build the neural network classifier :
class VoxelClassifier(nn.Module):
    def __init__(self):
        super(VoxelClassifier, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(4, 4),  # Input: 4 features, first hidden layer: 8 neurons
            nn.ReLU(),
            nn.Linear(4, 2)    # Output: 3 classes
        )

    def forward(self, x):
        return self.model(x)

# %%
model = VoxelClassifier()

# Check if GPU is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

# Move model to GPU
model.to(device)
# Out:
# cuda
# VoxelClassifier(
#   (model): Sequential(
#     (0): Linear(in_features=4, out_features=4, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=4, out_features=2, bias=True)
#   )
# )

# %%
# Convert your training data into PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)  # Features
y_train_tensor = torch.tensor(y_train, dtype=torch.long).to(device)    # Labels

# %%
batch_size = len(X_train) // 3

train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %%
# Loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Training and validation loop
num_epochs = 1000
for epoch in range(num_epochs):

    print(fr"-------------------- Epoch", epoch+1, "--------------------")
    # Training phase
    model.train()
    running_loss = 0.0
    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()           # Zero gradients
        outputs = model(X_batch)        # Forward pass
        loss = criterion(outputs, y_batch)  # Compute loss
        loss.backward()                 # Backward pass
        optimizer.step()                # Update weights

        running_loss += loss.item()

    train_loss = running_loss / len(train_loader)

    # Validation phase
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for X_batch, y_batch in train_loader:
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            val_loss += loss.item()

            # Accuracy calculation
            predicted = outputs.argmax(dim=1)
            correct += (predicted == y_batch).sum().item()
            total += y_batch.size(0)

    val_loss /= len(train_loader)
    val_accuracy = correct / total

    # Log metrics
    print(f"Epoch {epoch+1}/{num_epochs}:")
    print(f"  Training Loss: {train_loss:.4f}")
    print(f"  Validation Loss: {val_loss:.4f}")
    print(f"  Validation Accuracy: {val_accuracy:.4f}")

    # Optional: Log GPU memory usage
    print(f"  GPU Memory Allocated: {torch.cuda.memory_allocated() / 1e9:.2f} GB")
    print(f"  GPU Memory Reserved: {torch.cuda.memory_reserved() / 1e9:.2f} GB")
# Out:
# -------------------- Epoch 1 --------------------
# Epoch 1/1000:
#   Training Loss: 0.7283
#   Validation Loss: 0.6410
#   Validation Accuracy: 0.6749
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 2 --------------------
# Epoch 2/1000:
#   Training Loss: 0.6203
#   Validation Loss: 0.5916
#   Validation Accuracy: 0.7562
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 3 --------------------
# Epoch 3/1000:
#   Training Loss: 0.5817
#   Validation Loss: 0.5583
#   Validation Accuracy: 0.7725
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 4 --------------------
# Epoch 4/1000:
#   Training Loss: 0.5424
#   Validation Loss: 0.5089
#   Validation Accuracy: 0.7849
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 5 --------------------
# Epoch 5/1000:
#   Training Loss: 0.4929
#   Validation Loss: 0.4643
#   Validation Accuracy: 0.7949
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 6 --------------------
# Epoch 6/1000:
#   Training Loss: 0.4532
#   Validation Loss: 0.4334
#   Validation Accuracy: 0.8057
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 7 --------------------
# Epoch 7/1000:
#   Training Loss: 0.4236
#   Validation Loss: 0.4029
#   Validation Accuracy: 0.8232
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 8 --------------------
# Epoch 8/1000:
#   Training Loss: 0.3916
#   Validation Loss: 0.3693
#   Validation Accuracy: 0.8460
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 9 --------------------
# Epoch 9/1000:
#   Training Loss: 0.3592
#   Validation Loss: 0.3405
#   Validation Accuracy: 0.8592
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 10 --------------------
# Epoch 10/1000:
#   Training Loss: 0.3323
#   Validation Loss: 0.3168
#   Validation Accuracy: 0.8728
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 11 --------------------
# Epoch 11/1000:
#   Training Loss: 0.3092
#   Validation Loss: 0.2943
#   Validation Accuracy: 0.8910
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 12 --------------------
# Epoch 12/1000:
#   Training Loss: 0.2871
#   Validation Loss: 0.2735
#   Validation Accuracy: 0.9101
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 13 --------------------
# Epoch 13/1000:
#   Training Loss: 0.2674
#   Validation Loss: 0.2562
#   Validation Accuracy: 0.9242
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 14 --------------------
# Epoch 14/1000:
#   Training Loss: 0.2510
#   Validation Loss: 0.2409
#   Validation Accuracy: 0.9337
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 15 --------------------
# Epoch 15/1000:
#   Training Loss: 0.2361
#   Validation Loss: 0.2267
#   Validation Accuracy: 0.9403
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 16 --------------------
# Epoch 16/1000:
#   Training Loss: 0.2225
#   Validation Loss: 0.2145
#   Validation Accuracy: 0.9456
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 17 --------------------
# Epoch 17/1000:
#   Training Loss: 0.2109
#   Validation Loss: 0.2040
#   Validation Accuracy: 0.9494
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 18 --------------------
# Epoch 18/1000:
#   Training Loss: 0.2008
#   Validation Loss: 0.1945
#   Validation Accuracy: 0.9535
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 19 --------------------
# Epoch 19/1000:
#   Training Loss: 0.1916
#   Validation Loss: 0.1862
#   Validation Accuracy: 0.9579
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 20 --------------------
# Epoch 20/1000:
#   Training Loss: 0.1837
#   Validation Loss: 0.1789
#   Validation Accuracy: 0.9608
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 21 --------------------
# Epoch 21/1000:
#   Training Loss: 0.1767
#   Validation Loss: 0.1724
#   Validation Accuracy: 0.9624
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 22 --------------------
# Epoch 22/1000:
#   Training Loss: 0.1705
#   Validation Loss: 0.1666
#   Validation Accuracy: 0.9634
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 23 --------------------
# Epoch 23/1000:
#   Training Loss: 0.1649
#   Validation Loss: 0.1615
#   Validation Accuracy: 0.9645
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 24 --------------------
# Epoch 24/1000:
#   Training Loss: 0.1600
#   Validation Loss: 0.1569
#   Validation Accuracy: 0.9654
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 25 --------------------
# Epoch 25/1000:
#   Training Loss: 0.1555
#   Validation Loss: 0.1528
#   Validation Accuracy: 0.9659
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 26 --------------------
# Epoch 26/1000:
#   Training Loss: 0.1515
#   Validation Loss: 0.1490
#   Validation Accuracy: 0.9665
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 27 --------------------
# Epoch 27/1000:
#   Training Loss: 0.1479
#   Validation Loss: 0.1456
#   Validation Accuracy: 0.9668
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 28 --------------------
# Epoch 28/1000:
#   Training Loss: 0.1446
#   Validation Loss: 0.1425
#   Validation Accuracy: 0.9671
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 29 --------------------
# Epoch 29/1000:
#   Training Loss: 0.1415
#   Validation Loss: 0.1396
#   Validation Accuracy: 0.9671
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 30 --------------------
# Epoch 30/1000:
#   Training Loss: 0.1387
#   Validation Loss: 0.1370
#   Validation Accuracy: 0.9672
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 31 --------------------
# Epoch 31/1000:
#   Training Loss: 0.1362
#   Validation Loss: 0.1345
#   Validation Accuracy: 0.9673
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 32 --------------------
# Epoch 32/1000:
#   Training Loss: 0.1338
#   Validation Loss: 0.1323
#   Validation Accuracy: 0.9673
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 33 --------------------
# Epoch 33/1000:
#   Training Loss: 0.1316
#   Validation Loss: 0.1302
#   Validation Accuracy: 0.9675
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 34 --------------------
# Epoch 34/1000:
#   Training Loss: 0.1295
#   Validation Loss: 0.1282
#   Validation Accuracy: 0.9678
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 35 --------------------
# Epoch 35/1000:
#   Training Loss: 0.1275
#   Validation Loss: 0.1263
#   Validation Accuracy: 0.9679
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 36 --------------------
# Epoch 36/1000:
#   Training Loss: 0.1257
#   Validation Loss: 0.1246
#   Validation Accuracy: 0.9680
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 37 --------------------
# Epoch 37/1000:
#   Training Loss: 0.1240
#   Validation Loss: 0.1230
#   Validation Accuracy: 0.9680
#   GPU Memory Allocated: 0.05 GB
#   GPU Memory Reserved: 0.33 GB
# -------------------- Epoch 38 --------------------
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7ff4149f1e10>>
# Traceback (most recent call last):
#   File "/home/maichi/anaconda3/envs/env_aidream_registration/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:

# %%
# Let's now do the prediction on mask_pred :

pred_idx = np.array(np.nonzero(mask_pred.numpy()))
pred_intensity = ants_hammersmith.numpy()[pred_idx[0], pred_idx[1], pred_idx[2]]

df_pred = pd.DataFrame({"x": pred_idx[0], "y": pred_idx[1], "z": pred_idx[2], "intensity": pred_intensity})
X_pred = df_pred[["x", "y", "z", "intensity"]].values

X_pred_tensor = torch.tensor(X_pred, dtype=torch.float32).to(device)

model.eval()  # Set the model to evaluation mode

# Perform predictions
with torch.no_grad():
    outputs = model(X_pred_tensor)  # Raw model outputs (logits)
    predictions = outputs.argmax(dim=1)  # Predicted class labels

# Convert predictions to NumPy if needed
predictions_np = predictions.cpu().numpy() + 1

# %%
ants_prediction = ants.from_numpy(np.zeros(mask_1.shape), origin=mask_1.origin, spacing=mask_1.spacing, direction=mask_1.direction)

ants_prediction[pred_idx[0], pred_idx[1], pred_idx[2]] = predictions_np
ants_prediction[mask_1 == 1] = 1

# %%
path_prediction = constants.DIR_DATA / "hammersmith" / "custom" / "ventricle_prediction.nii.gz"
path_prediction.parent.mkdir(parents=True, exist_ok=True)
ants_prediction.to_file(str(path_prediction))

# %%
# # Let's do the prediction set on the voxels inside the ventricles' neighborhood  that are not segmented as ventricles :
# mask_pred = mask_ventricles_neighbors * (1 - mask_ventricles)
#
# pred_idx = np.array(np.nonzero(mask_pred.numpy()))
# pred_intensity = ants_hammersmith.numpy()[pred_idx[0], pred_idx[1], pred_idx[2]]
# df_pred = pd.DataFrame({"x": pred_idx[0], "y": pred_idx[1], "z": pred_idx[2], "intensity": pred_intensity})
#
# X_pred = df_pred[["x", "y", "z", "intensity"]].values
# print(f"Nuber of prediction samples: {len(X_pred)} / {mask_ventricles_neighbors.sum()}")

# %%
# # Now, let's treat the problem as a Machine Learning classification problem :
# # The training data will be the ventricles' segmentation and the voxels outside the ventricles' neighborhood.
# # The prediction will be done on the voxels inside the ventricles' neighborhood, that are not segmented as ventricles.
#
# # First, create the training data :
# # Add the ventricles' segmentation :
# ventricles_idx = np.array(np.nonzero(mask_ventricles.numpy()))
# ventricles_intensity = ants_hammersmith.numpy()[ventricles_idx[0], ventricles_idx[1], ventricles_idx[2]]
# df_ventricles = pd.DataFrame({"x": ventricles_idx[0], "y": ventricles_idx[1], "z": ventricles_idx[2],
#                               "intensity": ventricles_intensity, "label": 0})
#
# # now Add the voxels outside the ventricles' neighborhood that are CSF :
# csf_no_ventricles_neighbors_idx = np.array(np.nonzero(mask_csf_no_ventricles_neighbors.numpy()))
# csf_no_ventricles_neighbors_intensity = ants_hammersmith.numpy()[csf_no_ventricles_neighbors_idx[0], csf_no_ventricles_neighbors_idx[1], csf_no_ventricles_neighbors_idx[2]]
# df_csf_no_ventricles_neighbors = pd.DataFrame({"x": csf_no_ventricles_neighbors_idx[0], "y": csf_no_ventricles_neighbors_idx[1], "z": csf_no_ventricles_neighbors_idx[2],
#                                                "intensity": csf_no_ventricles_neighbors_intensity, "label": 1})
#
# # Now, add the voxels outside the ventricles' neighborhood that are not CSF :
# no_csf_no_ventricles_neighbors_idx = np.array(np.nonzero(mask_no_csf_no_ventricles_neighbors.numpy()))
# no_csf_no_ventricles_neighbors_intensity = ants_hammersmith.numpy()[no_csf_no_ventricles_neighbors_idx[0], no_csf_no_ventricles_neighbors_idx[1], no_csf_no_ventricles_neighbors_idx[2]]
# df_no_csf_no_ventricles_neighbors = pd.DataFrame({"x": no_csf_no_ventricles_neighbors_idx[0], "y": no_csf_no_ventricles_neighbors_idx[1], "z": no_csf_no_ventricles_neighbors_idx[2],
#                                                   "intensity": no_csf_no_ventricles_neighbors_intensity, "label": 2})
#
# # Concatenate the dataframes :
# df_train = pd.concat([df_ventricles, df_csf_no_ventricles_neighbors, df_no_csf_no_ventricles_neighbors], ignore_index=True)
# print(fr"len(df_train): {len(df_train)}")
#
# X_train, y_train = df_train[["x", "y", "z", "intensity"]].values, df_train["label"].values
#
# print(f"Number of training samples: {len(X_train)}")
#
# print(f"percentage of ventricles in the training set: {np.mean(y_train == 0):.2f}")
# print(f"percentage of CSF in the training set: {np.mean(y_train == 1):.2f}")
# print(f"percentage of brain in the training set: {np.mean(y_train == 2):.2f}")

# %%
# # Create a custom ventricles mask by combining the lateral ventricles and the third ventricle :
# mask_ventricles = dict_segmentations["L.Ventricles"] + dict_segmentations["R.Ventricles"] + dict_segmentations["third_ventricle"]
# mask_ventricles = mask_ventricles > 0
#
# print(f"Ventricles volume: {mask_ventricles.sum() / 1e3:.2f} cm3")
#
# path_ventricles = constants.DIR_DATA / "hammersmith" / "custom" / "total_ventricles" / "ventricles.nii.gz"
# path_ventricles.parent.mkdir(parents=True, exist_ok=True)
# mask_ventricles.to_file(str(path_ventricles))
# Out:
# Ventricles volume: 13.47 cm3

# %%
# # Create a bigger bounding box for the ventricles' neighborhood :
# seg_idx = np.array(np.nonzero(mask_ventricles.numpy()))
#
# bbox_min, bbox_max = np.min(seg_idx, axis=1), np.max(seg_idx, axis=1)
# bbox_min, bbox_max = bbox_min - 5, bbox_max + 5
#
# np_bbox = np.zeros(mask_ventricles.shape)
# np_bbox[bbox_min[0]: bbox_max[0], bbox_min[1]: bbox_max[1], bbox_min[2]: bbox_max[2]] = 1
#
# mask_big_ventricles_neighbors = (ants.from_numpy(np_bbox, origin=mask_ventricles.origin, spacing=mask_ventricles.spacing, direction=mask_ventricles.direction) > 0) * mask_hammersmith
#
# mask_hammersmith = (mask_big_ventricles_neighbors > 0) * mask_hammersmith
#
# print(fr"New Hammersmith mask volume: {mask_hammersmith.sum() / 1e3:.2f} cm3")
# Out:
# New Hammersmith mask volume: 540.69 cm3

# %%
# # Create a mask for the neighbors of the ventricles :
# dict_ventricles_neighbors = {}
#
# for seg in ["L.Ventricles", "R.Ventricles", "third_ventricle"]:
#
#     # Load the segmentation mask (prior) :
#     mask_segmentation = dict_segmentations[seg]
#     seg_idx = np.array(np.nonzero(mask_segmentation.numpy()))
#     # Bounding box :
#     bbox_min, bbox_max = np.min(seg_idx, axis=1), np.max(seg_idx, axis=1)
#     # Dilate by 3 voxels :
#     bbox_min, bbox_max = bbox_min - 3, bbox_max + 3
#     np_bbox = np.zeros(mask_segmentation.shape)
#     np_bbox[bbox_min[0]: bbox_max[0], bbox_min[1]: bbox_max[1], bbox_min[2]: bbox_max[2]] = 1
#
#     dict_ventricles_neighbors[seg] = (ants.from_numpy(np_bbox, origin=mask_segmentation.origin, spacing=mask_segmentation.spacing, direction=mask_segmentation.direction) > 0) * mask_hammersmith
#
# # Create mask_ventricles_neighborhood :
# mask_ventricles_neighbors = dict_ventricles_neighbors["L.Ventricles"] + dict_ventricles_neighbors["R.Ventricles"] + dict_ventricles_neighbors["third_ventricle"]
# mask_ventricles_neighbors = mask_ventricles_neighbors > 0
#
# print(f"Ventricles neighborhood volume: {mask_ventricles_neighbors.sum() / 1e3:.2f} cm3")
#
# # Create mask for brain without the ventricles' neighborhood :
# mask_brain = None
#
# for seg, mask_segmentation in dict_segmentations.items():
#
#     if seg not in ["L.Ventricles", "R.Ventricles", "third_ventricle"]:
#         if mask_brain is None:
#             mask_brain = mask_segmentation
#         else:
#             mask_brain += mask_segmentation
#
# mask_brain = (mask_brain > 0) * mask_hammersmith
#
# print(f"Brain without ventricles neighborhood volume: {mask_brain.sum() / 1e3:.2f} cm3")
# Out:
# Ventricles neighborhood volume: 440.61 cm3
# Brain without ventricles neighborhood volume: 361.43 cm3

# %%
# # Create a CSF segmentation for the voxels outside the ventricles that are not segmented :
# # Create a CSF segmentation for the voxels outside the ventricles that are not segmented :
# mask_csf_no_ventricles_neighbors = mask_no_ventricles_neighbors
#
# for seg, mask_segmentation in dict_segmentations.items():
#
#     if seg not in ["L.Ventricles", "R.Ventricles", "third_ventricle"]:
#         mask_csf_no_ventricles_neighbors = mask_csf_no_ventricles_neighbors * (1 - mask_segmentation)
#
# assert set(np.unique(mask_csf_no_ventricles_neighbors.numpy())) == {0, 1}
#
# print(f"CSF volume outside of the ventricles neighborhood: {mask_csf_no_ventricles_neighbors.sum() / 1e3:.2f} cm3")
#
# # Create a mask for the segmentations excluding the ventricles and the CSF :
# mask_no_csf_no_ventricles_neighbors = mask_no_ventricles_neighbors * (1 - mask_csf_no_ventricles_neighbors)
#
# print(f"Brain without ventricles and CSF volume: {mask_no_csf_no_ventricles_neighbors.sum() / 1e3:.2f} cm3")
# Out:
# CSF volume outside of the ventricles neighborhood: 19.44 cm3
# Brain without ventricles and CSF volume: 80.63 cm3

# %%
# radius = 1
# beta = 0.2
#
# mrf = f"[{beta}, {radius}x{radius}x{radius}]"
#
# print(fr"Applying Atropos with MRF = {mrf} ...")
#
# atropos_results = ants.atropos(a=[ants_hammersmith],
#                                x=mask_hammersmith,
#                                m=mrf,
#                                c="[10,0]",
#                                i=[mask_ventricles, mask_csf_no_ventricles_neighbors, mask_no_csf_no_ventricles_neighbors],
#                                verbose=1)
#
# ants_ventricles_atropos = (atropos_results["segmentation"] == 1) * mask_ventricles_neighbors
#
# path_ventricles_atropos = constants.DIR_DATA / "hammersmith" / "custom" / f"ventricle_atropos_{mrf}.nii.gz"
# path_ventricles_atropos.parent.mkdir(parents=True, exist_ok=True)
# ants_ventricles_atropos.to_file(str(path_ventricles_atropos))

# %%
# # Apply atropos to improve the quality fo the ventricles segmentation using the ventricles mask as a prior :
#
# radius = 1
# beta = 0.2
#
# mrf = f"[{beta}, {radius}x{radius}x{radius}]"
#
# print(fr"Applying Atropos with MRF = {mrf} ...")
#
# atropos_results = ants.atropos(a=[ants_hammersmith, ants_x_map, ants_y_map],
#                                x=mask_hammersmith,
#                                m=mrf,
#                                c="[10,0]",
#                                i=[mask_ventricles, mask_csf_no_ventricles_neighbors, mask_no_csf_no_ventricles_neighbors],
#                                verbose=1)
#
# ants_ventricles_atropos = (atropos_results["segmentation"] == 1) * mask_ventricles_neighbors
#
# path_ventricles_atropos = constants.DIR_DATA / "hammersmith" / "custom" / f"ventricle_atropos_{mrf}_coords.nii.gz"
# path_ventricles_atropos.parent.mkdir(parents=True, exist_ok=True)
# ants_ventricles_atropos.to_file(str(path_ventricles_atropos))

# %%
# # Now, let's treat the problem as a Machine Learning classification problem :
# # The training data will be the ventricles' segmentation and the voxels outside the ventricles' neighborhood.
# # The prediction will be done on the voxels inside the ventricles' neighborhood, that are not segmented as ventricles.
#
# # First, create the training data :
# # Add the ventricles' segmentation :
# ventricles_idx = np.array(np.nonzero(mask_ventricles.numpy()))
# ventricles_intensity = ants_hammersmith.numpy()[ventricles_idx[0], ventricles_idx[1], ventricles_idx[2]]
# df_ventricles = pd.DataFrame({"x": ventricles_idx[0], "y": ventricles_idx[1], "z": ventricles_idx[2],
#                               "intensity": ventricles_intensity, "label": 0})
#
# # now Add the voxels outside the ventricles' neighborhood that are CSF :
# csf_no_ventricles_neighbors_idx = np.array(np.nonzero(mask_csf_no_ventricles_neighbors.numpy()))
# csf_no_ventricles_neighbors_intensity = ants_hammersmith.numpy()[csf_no_ventricles_neighbors_idx[0], csf_no_ventricles_neighbors_idx[1], csf_no_ventricles_neighbors_idx[2]]
# df_csf_no_ventricles_neighbors = pd.DataFrame({"x": csf_no_ventricles_neighbors_idx[0], "y": csf_no_ventricles_neighbors_idx[1], "z": csf_no_ventricles_neighbors_idx[2],
#                                                "intensity": csf_no_ventricles_neighbors_intensity, "label": 1})
#
# # Now, add the voxels outside the ventricles' neighborhood that are not CSF :
# no_csf_no_ventricles_neighbors_idx = np.array(np.nonzero(mask_no_csf_no_ventricles_neighbors.numpy()))
# no_csf_no_ventricles_neighbors_intensity = ants_hammersmith.numpy()[no_csf_no_ventricles_neighbors_idx[0], no_csf_no_ventricles_neighbors_idx[1], no_csf_no_ventricles_neighbors_idx[2]]
# df_no_csf_no_ventricles_neighbors = pd.DataFrame({"x": no_csf_no_ventricles_neighbors_idx[0], "y": no_csf_no_ventricles_neighbors_idx[1], "z": no_csf_no_ventricles_neighbors_idx[2],
#                                                   "intensity": no_csf_no_ventricles_neighbors_intensity, "label": 2})
#
# # Concatenate the dataframes :
# df_train = pd.concat([df_ventricles, df_csf_no_ventricles_neighbors, df_no_csf_no_ventricles_neighbors], ignore_index=True)
# print(fr"len(df_train): {len(df_train)}")
#
# X_train, y_train = df_train[["x", "y", "z", "intensity"]].values, df_train["label"].values
#
# print(f"Number of training samples: {len(X_train)}")
#
# print(f"percentage of ventricles in the training set: {np.mean(y_train == 0):.2f}")
# print(f"percentage of CSF in the training set: {np.mean(y_train == 1):.2f}")
# print(f"percentage of brain in the training set: {np.mean(y_train == 2):.2f}")
# Out:
# len(df_train): 113541
# Number of training samples: 113541
# percentage of ventricles in the training set: 0.12
# percentage of CSF in the training set: 0.17
# percentage of brain in the training set: 0.71

# %%
# # Let's resample the training data to balance the classes :
# ventricles = df_train[df_train["label"] == 0]
# csf = df_train[df_train["label"] == 1]
# brain = df_train[df_train["label"] == 2]
#
# # the desired distribution is 3:3:4
# desired_ventricles_size = desired_csf_size = int(len(df_train) * 0.3)
# desired_brain_size = len(df_train) - desired_ventricles_size - desired_csf_size
#
# # Oversampling the ventricles and the CSF :
# ventricles_resampled = resample(ventricles, n_samples=desired_ventricles_size, replace=True, random_state=42)
# csf_resampled = resample(csf, n_samples=desired_csf_size, replace=True, random_state=42)
#
# # Downsampling the brain :
# brain_resampled = resample(brain, n_samples=desired_brain_size, replace=False, random_state=42)
#
# # Concatenate the resampled dataframes :
# df_train_resampled = pd.concat([ventricles_resampled, csf_resampled, brain_resampled], ignore_index=True)
#
# X_train, X_val, y_train, y_val = train_test_split(df_train_resampled[["x", "y", "z", "intensity"]].values, df_train_resampled["label"].values, test_size=0.2, random_state=42)
#
# print(f"Number of training samples: {len(X_train)}")
# print(f"Number of validation samples: {len(X_val)}")
#
# print(f"percentage of ventricles in the training set: {np.mean(y_train == 0):.2f}, and in the validation set: {np.mean(y_val == 0):.2f}")
# print(f"percentage of CSF in the training set: {np.mean(y_train == 1):.2f}, and in the validation set: {np.mean(y_val == 1):.2f}")
# print(f"percentage of brain in the training set: {np.mean(y_train == 2):.2f}, and in the validation set: {np.mean(y_val == 2):.2f}")
# Out:
# Number of training samples: 90832
# Number of validation samples: 22709
# percentage of ventricles in the training set: 0.30, and in the validation set: 0.30
# percentage of CSF in the training set: 0.30, and in the validation set: 0.30
# percentage of brain in the training set: 0.40, and in the validation set: 0.40

# %%
# # Let's do the prediction set on the voxels inside the ventricles' neighborhood  that are not segmented as ventricles :
# mask_pred = mask_ventricles_neighbors * (1 - mask_ventricles)
#
# pred_idx = np.array(np.nonzero(mask_pred.numpy()))
# pred_intensity = ants_hammersmith.numpy()[pred_idx[0], pred_idx[1], pred_idx[2]]
# df_pred = pd.DataFrame({"x": pred_idx[0], "y": pred_idx[1], "z": pred_idx[2], "intensity": pred_intensity})
#
# X_pred = df_pred[["x", "y", "z", "intensity"]].values
# print(f"Nuber of prediction samples: {len(X_pred)} / {mask_ventricles_neighbors.sum()}")
# Out:
# Nuber of prediction samples: 427148 / 440611

# %%
# # Build the neural network classifier :
# class VoxelClassifier(nn.Module):
#     def __init__(self):
#         super(VoxelClassifier, self).__init__()
#         self.model = nn.Sequential(
#             nn.Linear(4, 4),  # Input: 4 features, first hidden layer: 8 neurons
#             nn.ReLU(),
#             nn.Linear(4, 3)    # Output: 3 classes
#         )
#
#     def forward(self, x):
#         return self.model(x)

# %%
# model = VoxelClassifier()
#
# # Check if GPU is available
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# print(device)
#
# # Move model to GPU
# model.to(device)
# Out:
# cuda
# VoxelClassifier(
#   (model): Sequential(
#     (0): Linear(in_features=4, out_features=4, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=4, out_features=3, bias=True)
#   )
# )

# %%
# Convert your training data into PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)  # Features
y_train_tensor = torch.tensor(y_train, dtype=torch.long).to(device)    # Labels

# Convert your validation data into PyTorch tensors
X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)  # Features
y_val_tensor = torch.tensor(y_val, dtype=torch.long).to(device)    # Labels

# %%
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)

batch_size = 2000

train_loader = DataLoader(train_dataset, batch_size=90832, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=22709, shuffle=False)

# Verify DataLoaders by iterating through one batch
for X_batch, y_batch in train_loader:
    print("Training Batch:")
    print("  Features Shape:", X_batch.shape)
    print("  Labels Shape:", y_batch.shape)
    print("  Label Counts:", torch.bincount(y_batch))
    break  # Check only the first batch

for X_batch, y_batch in val_loader:
    print("Validation Batch:")
    print("  Features Shape:", X_batch.shape)
    print("  Labels Shape:", y_batch.shape)
    print("  Label Counts:", torch.bincount(y_batch))
    break  # Check only the first batch
# Out:
# Training Batch:
#   Features Shape: torch.Size([90832, 4])
#   Labels Shape: torch.Size([90832])
#   Label Counts: tensor([27210, 27191, 36431], device='cuda:0')
# Validation Batch:
#   Features Shape: torch.Size([22709, 4])
#   Labels Shape: torch.Size([22709])
#   Label Counts: tensor([6852, 6871, 8986], device='cuda:0')

# %%
# Loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Training and validation loop
num_epochs = 10000
for epoch in range(num_epochs):

    print(fr"-------------------- Epoch", epoch+1, "--------------------")
    # Training phase
    model.train()
    running_loss = 0.0
    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()           # Zero gradients
        outputs = model(X_batch)        # Forward pass
        loss = criterion(outputs, y_batch)  # Compute loss
        loss.backward()                 # Backward pass
        optimizer.step()                # Update weights

        running_loss += loss.item()

    train_loss = running_loss / len(train_loader)

    # Validation phase
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            val_loss += loss.item()

            # Accuracy calculation
            predicted = outputs.argmax(dim=1)
            correct += (predicted == y_batch).sum().item()
            total += y_batch.size(0)

    val_loss /= len(val_loader)
    val_accuracy = correct / total

    # Log metrics
    print(f"Epoch {epoch+1}/{num_epochs}:")
    print(f"  Training Loss: {train_loss:.4f}")
    print(f"  Validation Loss: {val_loss:.4f}")
    print(f"  Validation Accuracy: {val_accuracy:.4f}")

    # Optional: Log GPU memory usage
    print(f"  GPU Memory Allocated: {torch.cuda.memory_allocated() / 1e9:.2f} GB")
    print(f"  GPU Memory Reserved: {torch.cuda.memory_reserved() / 1e9:.2f} GB")
# Out:
# -------------------- Epoch 1 --------------------
# Epoch 1/10000:
#   Training Loss: 17.4586
#   Validation Loss: 17.3820
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 2 --------------------
# Epoch 2/10000:
#   Training Loss: 17.2700
#   Validation Loss: 17.1944
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 3 --------------------
# Epoch 3/10000:
#   Training Loss: 17.0825
#   Validation Loss: 17.0078
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 4 --------------------
# Epoch 4/10000:
#   Training Loss: 16.8960
#   Validation Loss: 16.8223
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 5 --------------------
# Epoch 5/10000:
#   Training Loss: 16.7106
#   Validation Loss: 16.6379
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 6 --------------------
# Epoch 6/10000:
#   Training Loss: 16.5262
#   Validation Loss: 16.4546
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 7 --------------------
# Epoch 7/10000:
#   Training Loss: 16.3431
#   Validation Loss: 16.2725
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 8 --------------------
# Epoch 8/10000:
#   Training Loss: 16.1610
#   Validation Loss: 16.0915
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 9 --------------------
# Epoch 9/10000:
#   Training Loss: 15.9801
#   Validation Loss: 15.9117
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 10 --------------------
# Epoch 10/10000:
#   Training Loss: 15.8004
#   Validation Loss: 15.7331
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 11 --------------------
# Epoch 11/10000:
#   Training Loss: 15.6220
#   Validation Loss: 15.5557
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 12 --------------------
# Epoch 12/10000:
#   Training Loss: 15.4447
#   Validation Loss: 15.3796
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 13 --------------------
# Epoch 13/10000:
#   Training Loss: 15.2688
#   Validation Loss: 15.2048
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 14 --------------------
# Epoch 14/10000:
#   Training Loss: 15.0941
#   Validation Loss: 15.0313
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 15 --------------------
# Epoch 15/10000:
#   Training Loss: 14.9208
#   Validation Loss: 14.8592
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 16 --------------------
# Epoch 16/10000:
#   Training Loss: 14.7488
#   Validation Loss: 14.6885
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 17 --------------------
# Epoch 17/10000:
#   Training Loss: 14.5781
#   Validation Loss: 14.5191
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 18 --------------------
# Epoch 18/10000:
#   Training Loss: 14.4089
#   Validation Loss: 14.3513
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 19 --------------------
# Epoch 19/10000:
#   Training Loss: 14.2412
#   Validation Loss: 14.1849
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 20 --------------------
# Epoch 20/10000:
#   Training Loss: 14.0750
#   Validation Loss: 14.0201
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 21 --------------------
# Epoch 21/10000:
#   Training Loss: 13.9104
#   Validation Loss: 13.8569
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 22 --------------------
# Epoch 22/10000:
#   Training Loss: 13.7473
#   Validation Loss: 13.6954
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 23 --------------------
# Epoch 23/10000:
#   Training Loss: 13.5859
#   Validation Loss: 13.5356
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 24 --------------------
# Epoch 24/10000:
#   Training Loss: 13.4263
#   Validation Loss: 13.3775
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 25 --------------------
# Epoch 25/10000:
#   Training Loss: 13.2684
#   Validation Loss: 13.2214
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 26 --------------------
# Epoch 26/10000:
#   Training Loss: 13.1124
#   Validation Loss: 13.0672
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 27 --------------------
# Epoch 27/10000:
#   Training Loss: 12.9584
#   Validation Loss: 12.9150
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 28 --------------------
# Epoch 28/10000:
#   Training Loss: 12.8064
#   Validation Loss: 12.7650
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 29 --------------------
# Epoch 29/10000:
#   Training Loss: 12.6566
#   Validation Loss: 12.6172
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 30 --------------------
# Epoch 30/10000:
#   Training Loss: 12.5089
#   Validation Loss: 12.4717
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 31 --------------------
# Epoch 31/10000:
#   Training Loss: 12.3637
#   Validation Loss: 12.3287
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 32 --------------------
# Epoch 32/10000:
#   Training Loss: 12.2209
#   Validation Loss: 12.1883
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 33 --------------------
# Epoch 33/10000:
#   Training Loss: 12.0807
#   Validation Loss: 12.0506
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 34 --------------------
# Epoch 34/10000:
#   Training Loss: 11.9432
#   Validation Loss: 11.9157
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 35 --------------------
# Epoch 35/10000:
#   Training Loss: 11.8085
#   Validation Loss: 11.7839
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 36 --------------------
# Epoch 36/10000:
#   Training Loss: 11.6769
#   Validation Loss: 11.6551
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 37 --------------------
# Epoch 37/10000:
#   Training Loss: 11.5483
#   Validation Loss: 11.5295
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 38 --------------------
# Epoch 38/10000:
#   Training Loss: 11.4230
#   Validation Loss: 11.4073
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 39 --------------------
# Epoch 39/10000:
#   Training Loss: 11.3010
#   Validation Loss: 11.2886
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 40 --------------------
# Epoch 40/10000:
#   Training Loss: 11.1825
#   Validation Loss: 11.1734
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 41 --------------------
# Epoch 41/10000:
#   Training Loss: 11.0676
#   Validation Loss: 11.0618
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 42 --------------------
# Epoch 42/10000:
#   Training Loss: 10.9562
#   Validation Loss: 10.9538
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 43 --------------------
# Epoch 43/10000:
#   Training Loss: 10.8485
#   Validation Loss: 10.8494
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 44 --------------------
# Epoch 44/10000:
#   Training Loss: 10.7444
#   Validation Loss: 10.7487
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 45 --------------------
# Epoch 45/10000:
#   Training Loss: 10.6439
#   Validation Loss: 10.6514
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 46 --------------------
# Epoch 46/10000:
#   Training Loss: 10.5470
#   Validation Loss: 10.5576
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 47 --------------------
# Epoch 47/10000:
#   Training Loss: 10.4535
#   Validation Loss: 10.4671
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 48 --------------------
# Epoch 48/10000:
#   Training Loss: 10.3633
#   Validation Loss: 10.3797
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 49 --------------------
# Epoch 49/10000:
#   Training Loss: 10.2763
#   Validation Loss: 10.2953
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 50 --------------------
# Epoch 50/10000:
#   Training Loss: 10.1922
#   Validation Loss: 10.2136
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 51 --------------------
# Epoch 51/10000:
#   Training Loss: 10.1108
#   Validation Loss: 10.1343
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 52 --------------------
# Epoch 52/10000:
#   Training Loss: 10.0320
#   Validation Loss: 10.0573
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 53 --------------------
# Epoch 53/10000:
#   Training Loss: 9.9553
#   Validation Loss: 9.9823
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 54 --------------------
# Epoch 54/10000:
#   Training Loss: 9.8808
#   Validation Loss: 9.9091
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 55 --------------------
# Epoch 55/10000:
#   Training Loss: 9.8080
#   Validation Loss: 9.8374
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 56 --------------------
# Epoch 56/10000:
#   Training Loss: 9.7367
#   Validation Loss: 9.7670
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 57 --------------------
# Epoch 57/10000:
#   Training Loss: 9.6668
#   Validation Loss: 9.6977
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 58 --------------------
# Epoch 58/10000:
#   Training Loss: 9.5980
#   Validation Loss: 9.6294
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 59 --------------------
# Epoch 59/10000:
#   Training Loss: 9.5301
#   Validation Loss: 9.5619
#   Validation Accuracy: 0.3189
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 60 --------------------
# Epoch 60/10000:
#   Training Loss: 9.4631
#   Validation Loss: 9.4949
#   Validation Accuracy: 0.2503
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 61 --------------------
# Epoch 61/10000:
#   Training Loss: 9.3967
#   Validation Loss: 9.4285
#   Validation Accuracy: 0.2996
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 62 --------------------
# Epoch 62/10000:
#   Training Loss: 9.3308
#   Validation Loss: 9.3626
#   Validation Accuracy: 0.3350
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 63 --------------------
# Epoch 63/10000:
#   Training Loss: 9.2654
#   Validation Loss: 9.2969
#   Validation Accuracy: 0.3632
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 64 --------------------
# Epoch 64/10000:
#   Training Loss: 9.2003
#   Validation Loss: 9.2315
#   Validation Accuracy: 0.3836
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 65 --------------------
# Epoch 65/10000:
#   Training Loss: 9.1355
#   Validation Loss: 9.1664
#   Validation Accuracy: 0.3923
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 66 --------------------
# Epoch 66/10000:
#   Training Loss: 9.0709
#   Validation Loss: 9.1014
#   Validation Accuracy: 0.3945
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 67 --------------------
# Epoch 67/10000:
#   Training Loss: 9.0065
#   Validation Loss: 9.0367
#   Validation Accuracy: 0.3956
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 68 --------------------
# Epoch 68/10000:
#   Training Loss: 8.9423
#   Validation Loss: 8.9720
#   Validation Accuracy: 0.3956
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 69 --------------------
# Epoch 69/10000:
#   Training Loss: 8.8783
#   Validation Loss: 8.9075
#   Validation Accuracy: 0.3957
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 70 --------------------
# Epoch 70/10000:
#   Training Loss: 8.8144
#   Validation Loss: 8.8432
#   Validation Accuracy: 0.3957
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 71 --------------------
# Epoch 71/10000:
#   Training Loss: 8.7507
#   Validation Loss: 8.7790
#   Validation Accuracy: 0.3957
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 72 --------------------
# Epoch 72/10000:
#   Training Loss: 8.6871
#   Validation Loss: 8.7149
#   Validation Accuracy: 0.3957
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 73 --------------------
# Epoch 73/10000:
#   Training Loss: 8.6237
#   Validation Loss: 8.6511
#   Validation Accuracy: 0.3957
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 74 --------------------
# Epoch 74/10000:
#   Training Loss: 8.5604
#   Validation Loss: 8.5874
#   Validation Accuracy: 0.3957
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 75 --------------------
# Epoch 75/10000:
#   Training Loss: 8.4974
#   Validation Loss: 8.5239
#   Validation Accuracy: 0.3956
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 76 --------------------
# Epoch 76/10000:
#   Training Loss: 8.4345
#   Validation Loss: 8.4606
#   Validation Accuracy: 0.3956
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 77 --------------------
# Epoch 77/10000:
#   Training Loss: 8.3719
#   Validation Loss: 8.3975
#   Validation Accuracy: 0.3948
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 78 --------------------
# Epoch 78/10000:
#   Training Loss: 8.3094
#   Validation Loss: 8.3347
#   Validation Accuracy: 0.3942
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 79 --------------------
# Epoch 79/10000:
#   Training Loss: 8.2472
#   Validation Loss: 8.2721
#   Validation Accuracy: 0.3928
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 80 --------------------
# Epoch 80/10000:
#   Training Loss: 8.1852
#   Validation Loss: 8.2097
#   Validation Accuracy: 0.3902
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 81 --------------------
# Epoch 81/10000:
#   Training Loss: 8.1235
#   Validation Loss: 8.1476
#   Validation Accuracy: 0.3845
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 82 --------------------
# Epoch 82/10000:
#   Training Loss: 8.0621
#   Validation Loss: 8.0858
#   Validation Accuracy: 0.3747
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 83 --------------------
# Epoch 83/10000:
#   Training Loss: 8.0009
#   Validation Loss: 8.0242
#   Validation Accuracy: 0.3647
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 84 --------------------
# Epoch 84/10000:
#   Training Loss: 7.9400
#   Validation Loss: 7.9630
#   Validation Accuracy: 0.3539
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 85 --------------------
# Epoch 85/10000:
#   Training Loss: 7.8793
#   Validation Loss: 7.9020
#   Validation Accuracy: 0.3426
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 86 --------------------
# Epoch 86/10000:
#   Training Loss: 7.8190
#   Validation Loss: 7.8413
#   Validation Accuracy: 0.3331
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 87 --------------------
# Epoch 87/10000:
#   Training Loss: 7.7589
#   Validation Loss: 7.7809
#   Validation Accuracy: 0.3240
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 88 --------------------
# Epoch 88/10000:
#   Training Loss: 7.6991
#   Validation Loss: 7.7208
#   Validation Accuracy: 0.3111
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 89 --------------------
# Epoch 89/10000:
#   Training Loss: 7.6396
#   Validation Loss: 7.6609
#   Validation Accuracy: 0.2983
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 90 --------------------
# Epoch 90/10000:
#   Training Loss: 7.5804
#   Validation Loss: 7.6014
#   Validation Accuracy: 0.2812
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 91 --------------------
# Epoch 91/10000:
#   Training Loss: 7.5215
#   Validation Loss: 7.5422
#   Validation Accuracy: 0.2672
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 92 --------------------
# Epoch 92/10000:
#   Training Loss: 7.4629
#   Validation Loss: 7.4832
#   Validation Accuracy: 0.2524
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 93 --------------------
# Epoch 93/10000:
#   Training Loss: 7.4045
#   Validation Loss: 7.4245
#   Validation Accuracy: 0.2370
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 94 --------------------
# Epoch 94/10000:
#   Training Loss: 7.3465
#   Validation Loss: 7.3662
#   Validation Accuracy: 0.2194
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 95 --------------------
# Epoch 95/10000:
#   Training Loss: 7.2887
#   Validation Loss: 7.3081
#   Validation Accuracy: 0.2128
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 96 --------------------
# Epoch 96/10000:
#   Training Loss: 7.2312
#   Validation Loss: 7.2503
#   Validation Accuracy: 0.2201
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 97 --------------------
# Epoch 97/10000:
#   Training Loss: 7.1740
#   Validation Loss: 7.1927
#   Validation Accuracy: 0.2482
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 98 --------------------
# Epoch 98/10000:
#   Training Loss: 7.1170
#   Validation Loss: 7.1355
#   Validation Accuracy: 0.2852
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 99 --------------------
# Epoch 99/10000:
#   Training Loss: 7.0603
#   Validation Loss: 7.0785
#   Validation Accuracy: 0.3133
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 100 --------------------
# Epoch 100/10000:
#   Training Loss: 7.0040
#   Validation Loss: 7.0218
#   Validation Accuracy: 0.3175
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 101 --------------------
# Epoch 101/10000:
#   Training Loss: 6.9478
#   Validation Loss: 6.9654
#   Validation Accuracy: 0.3083
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 102 --------------------
# Epoch 102/10000:
#   Training Loss: 6.8920
#   Validation Loss: 6.9092
#   Validation Accuracy: 0.3030
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 103 --------------------
# Epoch 103/10000:
#   Training Loss: 6.8364
#   Validation Loss: 6.8533
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 104 --------------------
# Epoch 104/10000:
#   Training Loss: 6.7811
#   Validation Loss: 6.7977
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 105 --------------------
# Epoch 105/10000:
#   Training Loss: 6.7260
#   Validation Loss: 6.7424
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 106 --------------------
# Epoch 106/10000:
#   Training Loss: 6.6712
#   Validation Loss: 6.6873
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 107 --------------------
# Epoch 107/10000:
#   Training Loss: 6.6167
#   Validation Loss: 6.6325
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 108 --------------------
# Epoch 108/10000:
#   Training Loss: 6.5624
#   Validation Loss: 6.5779
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 109 --------------------
# Epoch 109/10000:
#   Training Loss: 6.5084
#   Validation Loss: 6.5236
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 110 --------------------
# Epoch 110/10000:
#   Training Loss: 6.4547
#   Validation Loss: 6.4696
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 111 --------------------
# Epoch 111/10000:
#   Training Loss: 6.4012
#   Validation Loss: 6.4159
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 112 --------------------
# Epoch 112/10000:
#   Training Loss: 6.3480
#   Validation Loss: 6.3623
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 113 --------------------
# Epoch 113/10000:
#   Training Loss: 6.2950
#   Validation Loss: 6.3091
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 114 --------------------
# Epoch 114/10000:
#   Training Loss: 6.2423
#   Validation Loss: 6.2561
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 115 --------------------
# Epoch 115/10000:
#   Training Loss: 6.1898
#   Validation Loss: 6.2034
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 116 --------------------
# Epoch 116/10000:
#   Training Loss: 6.1376
#   Validation Loss: 6.1509
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 117 --------------------
# Epoch 117/10000:
#   Training Loss: 6.0857
#   Validation Loss: 6.0987
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 118 --------------------
# Epoch 118/10000:
#   Training Loss: 6.0340
#   Validation Loss: 6.0467
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 119 --------------------
# Epoch 119/10000:
#   Training Loss: 5.9825
#   Validation Loss: 5.9950
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 120 --------------------
# Epoch 120/10000:
#   Training Loss: 5.9313
#   Validation Loss: 5.9436
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 121 --------------------
# Epoch 121/10000:
#   Training Loss: 5.8804
#   Validation Loss: 5.8924
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 122 --------------------
# Epoch 122/10000:
#   Training Loss: 5.8297
#   Validation Loss: 5.8415
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 123 --------------------
# Epoch 123/10000:
#   Training Loss: 5.7793
#   Validation Loss: 5.7908
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 124 --------------------
# Epoch 124/10000:
#   Training Loss: 5.7291
#   Validation Loss: 5.7403
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 125 --------------------
# Epoch 125/10000:
#   Training Loss: 5.6791
#   Validation Loss: 5.6901
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 126 --------------------
# Epoch 126/10000:
#   Training Loss: 5.6295
#   Validation Loss: 5.6402
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 127 --------------------
# Epoch 127/10000:
#   Training Loss: 5.5800
#   Validation Loss: 5.5905
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 128 --------------------
# Epoch 128/10000:
#   Training Loss: 5.5308
#   Validation Loss: 5.5411
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 129 --------------------
# Epoch 129/10000:
#   Training Loss: 5.4819
#   Validation Loss: 5.4919
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 130 --------------------
# Epoch 130/10000:
#   Training Loss: 5.4332
#   Validation Loss: 5.4430
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 131 --------------------
# Epoch 131/10000:
#   Training Loss: 5.3847
#   Validation Loss: 5.3943
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 132 --------------------
# Epoch 132/10000:
#   Training Loss: 5.3365
#   Validation Loss: 5.3458
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 133 --------------------
# Epoch 133/10000:
#   Training Loss: 5.2885
#   Validation Loss: 5.2976
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 134 --------------------
# Epoch 134/10000:
#   Training Loss: 5.2408
#   Validation Loss: 5.2496
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 135 --------------------
# Epoch 135/10000:
#   Training Loss: 5.1933
#   Validation Loss: 5.2019
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 136 --------------------
# Epoch 136/10000:
#   Training Loss: 5.1460
#   Validation Loss: 5.1544
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 137 --------------------
# Epoch 137/10000:
#   Training Loss: 5.0990
#   Validation Loss: 5.1072
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 138 --------------------
# Epoch 138/10000:
#   Training Loss: 5.0522
#   Validation Loss: 5.0602
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 139 --------------------
# Epoch 139/10000:
#   Training Loss: 5.0057
#   Validation Loss: 5.0134
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 140 --------------------
# Epoch 140/10000:
#   Training Loss: 4.9594
#   Validation Loss: 4.9669
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 141 --------------------
# Epoch 141/10000:
#   Training Loss: 4.9133
#   Validation Loss: 4.9206
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 142 --------------------
# Epoch 142/10000:
#   Training Loss: 4.8675
#   Validation Loss: 4.8746
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 143 --------------------
# Epoch 143/10000:
#   Training Loss: 4.8219
#   Validation Loss: 4.8287
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 144 --------------------
# Epoch 144/10000:
#   Training Loss: 4.7765
#   Validation Loss: 4.7832
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 145 --------------------
# Epoch 145/10000:
#   Training Loss: 4.7314
#   Validation Loss: 4.7378
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 146 --------------------
# Epoch 146/10000:
#   Training Loss: 4.6865
#   Validation Loss: 4.6927
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 147 --------------------
# Epoch 147/10000:
#   Training Loss: 4.6418
#   Validation Loss: 4.6478
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 148 --------------------
# Epoch 148/10000:
#   Training Loss: 4.5974
#   Validation Loss: 4.6031
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 149 --------------------
# Epoch 149/10000:
#   Training Loss: 4.5531
#   Validation Loss: 4.5587
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 150 --------------------
# Epoch 150/10000:
#   Training Loss: 4.5092
#   Validation Loss: 4.5145
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 151 --------------------
# Epoch 151/10000:
#   Training Loss: 4.4654
#   Validation Loss: 4.4705
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 152 --------------------
# Epoch 152/10000:
#   Training Loss: 4.4218
#   Validation Loss: 4.4268
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 153 --------------------
# Epoch 153/10000:
#   Training Loss: 4.3785
#   Validation Loss: 4.3832
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 154 --------------------
# Epoch 154/10000:
#   Training Loss: 4.3354
#   Validation Loss: 4.3399
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 155 --------------------
# Epoch 155/10000:
#   Training Loss: 4.2925
#   Validation Loss: 4.2968
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 156 --------------------
# Epoch 156/10000:
#   Training Loss: 4.2499
#   Validation Loss: 4.2540
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 157 --------------------
# Epoch 157/10000:
#   Training Loss: 4.2074
#   Validation Loss: 4.2113
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 158 --------------------
# Epoch 158/10000:
#   Training Loss: 4.1652
#   Validation Loss: 4.1689
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 159 --------------------
# Epoch 159/10000:
#   Training Loss: 4.1232
#   Validation Loss: 4.1267
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 160 --------------------
# Epoch 160/10000:
#   Training Loss: 4.0814
#   Validation Loss: 4.0847
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 161 --------------------
# Epoch 161/10000:
#   Training Loss: 4.0398
#   Validation Loss: 4.0429
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 162 --------------------
# Epoch 162/10000:
#   Training Loss: 3.9985
#   Validation Loss: 4.0014
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 163 --------------------
# Epoch 163/10000:
#   Training Loss: 3.9573
#   Validation Loss: 3.9600
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 164 --------------------
# Epoch 164/10000:
#   Training Loss: 3.9164
#   Validation Loss: 3.9189
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 165 --------------------
# Epoch 165/10000:
#   Training Loss: 3.8757
#   Validation Loss: 3.8780
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 166 --------------------
# Epoch 166/10000:
#   Training Loss: 3.8352
#   Validation Loss: 3.8373
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 167 --------------------
# Epoch 167/10000:
#   Training Loss: 3.7949
#   Validation Loss: 3.7968
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 168 --------------------
# Epoch 168/10000:
#   Training Loss: 3.7548
#   Validation Loss: 3.7565
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 169 --------------------
# Epoch 169/10000:
#   Training Loss: 3.7149
#   Validation Loss: 3.7164
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 170 --------------------
# Epoch 170/10000:
#   Training Loss: 3.6752
#   Validation Loss: 3.6766
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 171 --------------------
# Epoch 171/10000:
#   Training Loss: 3.6357
#   Validation Loss: 3.6369
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 172 --------------------
# Epoch 172/10000:
#   Training Loss: 3.5965
#   Validation Loss: 3.5975
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 173 --------------------
# Epoch 173/10000:
#   Training Loss: 3.5574
#   Validation Loss: 3.5582
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 174 --------------------
# Epoch 174/10000:
#   Training Loss: 3.5186
#   Validation Loss: 3.5192
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 175 --------------------
# Epoch 175/10000:
#   Training Loss: 3.4799
#   Validation Loss: 3.4804
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 176 --------------------
# Epoch 176/10000:
#   Training Loss: 3.4415
#   Validation Loss: 3.4417
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 177 --------------------
# Epoch 177/10000:
#   Training Loss: 3.4033
#   Validation Loss: 3.4033
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 178 --------------------
# Epoch 178/10000:
#   Training Loss: 3.3652
#   Validation Loss: 3.3651
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 179 --------------------
# Epoch 179/10000:
#   Training Loss: 3.3274
#   Validation Loss: 3.3271
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 180 --------------------
# Epoch 180/10000:
#   Training Loss: 3.2898
#   Validation Loss: 3.2894
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 181 --------------------
# Epoch 181/10000:
#   Training Loss: 3.2524
#   Validation Loss: 3.2518
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 182 --------------------
# Epoch 182/10000:
#   Training Loss: 3.2152
#   Validation Loss: 3.2144
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 183 --------------------
# Epoch 183/10000:
#   Training Loss: 3.1783
#   Validation Loss: 3.1773
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 184 --------------------
# Epoch 184/10000:
#   Training Loss: 3.1415
#   Validation Loss: 3.1404
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 185 --------------------
# Epoch 185/10000:
#   Training Loss: 3.1049
#   Validation Loss: 3.1037
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 186 --------------------
# Epoch 186/10000:
#   Training Loss: 3.0686
#   Validation Loss: 3.0672
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 187 --------------------
# Epoch 187/10000:
#   Training Loss: 3.0325
#   Validation Loss: 3.0309
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 188 --------------------
# Epoch 188/10000:
#   Training Loss: 2.9966
#   Validation Loss: 2.9948
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 189 --------------------
# Epoch 189/10000:
#   Training Loss: 2.9609
#   Validation Loss: 2.9590
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 190 --------------------
# Epoch 190/10000:
#   Training Loss: 2.9254
#   Validation Loss: 2.9234
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 191 --------------------
# Epoch 191/10000:
#   Training Loss: 2.8902
#   Validation Loss: 2.8881
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 192 --------------------
# Epoch 192/10000:
#   Training Loss: 2.8552
#   Validation Loss: 2.8529
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 193 --------------------
# Epoch 193/10000:
#   Training Loss: 2.8204
#   Validation Loss: 2.8180
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 194 --------------------
# Epoch 194/10000:
#   Training Loss: 2.7859
#   Validation Loss: 2.7834
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 195 --------------------
# Epoch 195/10000:
#   Training Loss: 2.7516
#   Validation Loss: 2.7490
#   Validation Accuracy: 0.3017
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 196 --------------------
# Epoch 196/10000:
#   Training Loss: 2.7176
#   Validation Loss: 2.7148
#   Validation Accuracy: 0.3019
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 197 --------------------
# Epoch 197/10000:
#   Training Loss: 2.6838
#   Validation Loss: 2.6810
#   Validation Accuracy: 0.3022
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 198 --------------------
# Epoch 198/10000:
#   Training Loss: 2.6503
#   Validation Loss: 2.6473
#   Validation Accuracy: 0.3026
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 199 --------------------
# Epoch 199/10000:
#   Training Loss: 2.6170
#   Validation Loss: 2.6140
#   Validation Accuracy: 0.3029
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 200 --------------------
# Epoch 200/10000:
#   Training Loss: 2.5840
#   Validation Loss: 2.5809
#   Validation Accuracy: 0.3036
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 201 --------------------
# Epoch 201/10000:
#   Training Loss: 2.5513
#   Validation Loss: 2.5481
#   Validation Accuracy: 0.3041
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 202 --------------------
# Epoch 202/10000:
#   Training Loss: 2.5189
#   Validation Loss: 2.5156
#   Validation Accuracy: 0.3046
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 203 --------------------
# Epoch 203/10000:
#   Training Loss: 2.4868
#   Validation Loss: 2.4834
#   Validation Accuracy: 0.3053
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 204 --------------------
# Epoch 204/10000:
#   Training Loss: 2.4549
#   Validation Loss: 2.4515
#   Validation Accuracy: 0.3059
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 205 --------------------
# Epoch 205/10000:
#   Training Loss: 2.4234
#   Validation Loss: 2.4200
#   Validation Accuracy: 0.3060
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 206 --------------------
# Epoch 206/10000:
#   Training Loss: 2.3922
#   Validation Loss: 2.3887
#   Validation Accuracy: 0.3065
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 207 --------------------
# Epoch 207/10000:
#   Training Loss: 2.3613
#   Validation Loss: 2.3578
#   Validation Accuracy: 0.3069
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 208 --------------------
# Epoch 208/10000:
#   Training Loss: 2.3307
#   Validation Loss: 2.3272
#   Validation Accuracy: 0.3070
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 209 --------------------
# Epoch 209/10000:
#   Training Loss: 2.3005
#   Validation Loss: 2.2970
#   Validation Accuracy: 0.3074
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 210 --------------------
# Epoch 210/10000:
#   Training Loss: 2.2707
#   Validation Loss: 2.2671
#   Validation Accuracy: 0.3075
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 211 --------------------
# Epoch 211/10000:
#   Training Loss: 2.2411
#   Validation Loss: 2.2376
#   Validation Accuracy: 0.3077
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 212 --------------------
# Epoch 212/10000:
#   Training Loss: 2.2120
#   Validation Loss: 2.2085
#   Validation Accuracy: 0.3082
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 213 --------------------
# Epoch 213/10000:
#   Training Loss: 2.1832
#   Validation Loss: 2.1798
#   Validation Accuracy: 0.3090
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 214 --------------------
# Epoch 214/10000:
#   Training Loss: 2.1548
#   Validation Loss: 2.1514
#   Validation Accuracy: 0.3101
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 215 --------------------
# Epoch 215/10000:
#   Training Loss: 2.1268
#   Validation Loss: 2.1234
#   Validation Accuracy: 0.3111
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 216 --------------------
# Epoch 216/10000:
#   Training Loss: 2.0992
#   Validation Loss: 2.0958
#   Validation Accuracy: 0.3119
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 217 --------------------
# Epoch 217/10000:
#   Training Loss: 2.0720
#   Validation Loss: 2.0687
#   Validation Accuracy: 0.3129
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 218 --------------------
# Epoch 218/10000:
#   Training Loss: 2.0452
#   Validation Loss: 2.0419
#   Validation Accuracy: 0.3142
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 219 --------------------
# Epoch 219/10000:
#   Training Loss: 2.0188
#   Validation Loss: 2.0156
#   Validation Accuracy: 0.3162
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 220 --------------------
# Epoch 220/10000:
#   Training Loss: 1.9928
#   Validation Loss: 1.9897
#   Validation Accuracy: 0.3181
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 221 --------------------
# Epoch 221/10000:
#   Training Loss: 1.9673
#   Validation Loss: 1.9642
#   Validation Accuracy: 0.3205
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 222 --------------------
# Epoch 222/10000:
#   Training Loss: 1.9422
#   Validation Loss: 1.9393
#   Validation Accuracy: 0.3230
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 223 --------------------
# Epoch 223/10000:
#   Training Loss: 1.9176
#   Validation Loss: 1.9147
#   Validation Accuracy: 0.3244
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 224 --------------------
# Epoch 224/10000:
#   Training Loss: 1.8935
#   Validation Loss: 1.8907
#   Validation Accuracy: 0.3257
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 225 --------------------
# Epoch 225/10000:
#   Training Loss: 1.8698
#   Validation Loss: 1.8672
#   Validation Accuracy: 0.3278
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 226 --------------------
# Epoch 226/10000:
#   Training Loss: 1.8467
#   Validation Loss: 1.8442
#   Validation Accuracy: 0.3297
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 227 --------------------
# Epoch 227/10000:
#   Training Loss: 1.8240
#   Validation Loss: 1.8216
#   Validation Accuracy: 0.3323
#   GPU Memory Allocated: 0.02 GB
# ...
# Epoch 865/10000:
#   Training Loss: 0.9088
#   Validation Loss: 0.9101
#   Validation Accuracy: 0.5423
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 866 --------------------
# Epoch 866/10000:
#   Training Loss: 0.9084
#   Validation Loss: 0.9097
#   Validation Accuracy: 0.5422
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 867 --------------------
# Epoch 867/10000:
#   Training Loss: 0.9081
#   Validation Loss: 0.9094
#   Validation Accuracy: 0.5423
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 868 --------------------
# Epoch 868/10000:
#   Training Loss: 0.9078
#   Validation Loss: 0.9091
#   Validation Accuracy: 0.5424
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 869 --------------------
# Epoch 869/10000:
#   Training Loss: 0.9075
#   Validation Loss: 0.9087
#   Validation Accuracy: 0.5423
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 870 --------------------
# Epoch 870/10000:
#   Training Loss: 0.9071
#   Validation Loss: 0.9084
#   Validation Accuracy: 0.5423
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 871 --------------------
# Epoch 871/10000:
#   Training Loss: 0.9068
#   Validation Loss: 0.9081
#   Validation Accuracy: 0.5422
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 872 --------------------
# Epoch 872/10000:
#   Training Loss: 0.9065
#   Validation Loss: 0.9077
#   Validation Accuracy: 0.5423
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 873 --------------------
# Epoch 873/10000:
#   Training Loss: 0.9061
#   Validation Loss: 0.9074
#   Validation Accuracy: 0.5423
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 874 --------------------
# Epoch 874/10000:
#   Training Loss: 0.9058
#   Validation Loss: 0.9071
#   Validation Accuracy: 0.5424
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 875 --------------------
# Epoch 875/10000:
#   Training Loss: 0.9055
#   Validation Loss: 0.9067
#   Validation Accuracy: 0.5425
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 876 --------------------
# Epoch 876/10000:
#   Training Loss: 0.9052
#   Validation Loss: 0.9064
#   Validation Accuracy: 0.5425
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 877 --------------------
# Epoch 877/10000:
#   Training Loss: 0.9048
#   Validation Loss: 0.9061
#   Validation Accuracy: 0.5424
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 878 --------------------
# Epoch 878/10000:
#   Training Loss: 0.9045
#   Validation Loss: 0.9058
#   Validation Accuracy: 0.5424
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 879 --------------------
# Epoch 879/10000:
#   Training Loss: 0.9042
#   Validation Loss: 0.9054
#   Validation Accuracy: 0.5426
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 880 --------------------
# Epoch 880/10000:
#   Training Loss: 0.9038
#   Validation Loss: 0.9051
#   Validation Accuracy: 0.5427
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 881 --------------------
# Epoch 881/10000:
#   Training Loss: 0.9035
#   Validation Loss: 0.9048
#   Validation Accuracy: 0.5427
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 882 --------------------
# Epoch 882/10000:
#   Training Loss: 0.9032
#   Validation Loss: 0.9044
#   Validation Accuracy: 0.5429
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 883 --------------------
# Epoch 883/10000:
#   Training Loss: 0.9028
#   Validation Loss: 0.9041
#   Validation Accuracy: 0.5429
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 884 --------------------
# Epoch 884/10000:
#   Training Loss: 0.9025
#   Validation Loss: 0.9038
#   Validation Accuracy: 0.5430
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 885 --------------------
# Epoch 885/10000:
#   Training Loss: 0.9022
#   Validation Loss: 0.9034
#   Validation Accuracy: 0.5431
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 886 --------------------
# Epoch 886/10000:
#   Training Loss: 0.9018
#   Validation Loss: 0.9031
#   Validation Accuracy: 0.5431
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 887 --------------------
# Epoch 887/10000:
#   Training Loss: 0.9015
#   Validation Loss: 0.9028
#   Validation Accuracy: 0.5432
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 888 --------------------
# Epoch 888/10000:
#   Training Loss: 0.9012
#   Validation Loss: 0.9025
#   Validation Accuracy: 0.5432
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 889 --------------------
# Epoch 889/10000:
#   Training Loss: 0.9009
#   Validation Loss: 0.9021
#   Validation Accuracy: 0.5432
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 890 --------------------
# Epoch 890/10000:
#   Training Loss: 0.9005
#   Validation Loss: 0.9018
#   Validation Accuracy: 0.5432
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 891 --------------------
# Epoch 891/10000:
#   Training Loss: 0.9002
#   Validation Loss: 0.9015
#   Validation Accuracy: 0.5432
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 892 --------------------
# Epoch 892/10000:
#   Training Loss: 0.8999
#   Validation Loss: 0.9011
#   Validation Accuracy: 0.5432
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 893 --------------------
# Epoch 893/10000:
#   Training Loss: 0.8996
#   Validation Loss: 0.9008
#   Validation Accuracy: 0.5432
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 894 --------------------
# Epoch 894/10000:
#   Training Loss: 0.8992
#   Validation Loss: 0.9005
#   Validation Accuracy: 0.5434
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 895 --------------------
# Epoch 895/10000:
#   Training Loss: 0.8989
#   Validation Loss: 0.9001
#   Validation Accuracy: 0.5435
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 896 --------------------
# Epoch 896/10000:
#   Training Loss: 0.8986
#   Validation Loss: 0.8998
#   Validation Accuracy: 0.5435
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 897 --------------------
# Epoch 897/10000:
#   Training Loss: 0.8983
#   Validation Loss: 0.8995
#   Validation Accuracy: 0.5436
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 898 --------------------
# Epoch 898/10000:
#   Training Loss: 0.8979
#   Validation Loss: 0.8992
#   Validation Accuracy: 0.5437
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 899 --------------------
# Epoch 899/10000:
#   Training Loss: 0.8976
#   Validation Loss: 0.8988
#   Validation Accuracy: 0.5438
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 900 --------------------
# Epoch 900/10000:
#   Training Loss: 0.8973
#   Validation Loss: 0.8985
#   Validation Accuracy: 0.5437
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 901 --------------------
# Epoch 901/10000:
#   Training Loss: 0.8970
#   Validation Loss: 0.8982
#   Validation Accuracy: 0.5438
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 902 --------------------
# Epoch 902/10000:
#   Training Loss: 0.8966
#   Validation Loss: 0.8978
#   Validation Accuracy: 0.5439
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 903 --------------------
# Epoch 903/10000:
#   Training Loss: 0.8963
#   Validation Loss: 0.8975
#   Validation Accuracy: 0.5441
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 904 --------------------
# Epoch 904/10000:
#   Training Loss: 0.8960
#   Validation Loss: 0.8972
#   Validation Accuracy: 0.5441
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 905 --------------------
# Epoch 905/10000:
#   Training Loss: 0.8956
#   Validation Loss: 0.8968
#   Validation Accuracy: 0.5442
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 906 --------------------
# Epoch 906/10000:
#   Training Loss: 0.8953
#   Validation Loss: 0.8965
#   Validation Accuracy: 0.5442
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 907 --------------------
# Epoch 907/10000:
#   Training Loss: 0.8950
#   Validation Loss: 0.8962
#   Validation Accuracy: 0.5442
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 908 --------------------
# Epoch 908/10000:
#   Training Loss: 0.8946
#   Validation Loss: 0.8959
#   Validation Accuracy: 0.5442
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 909 --------------------
# Epoch 909/10000:
#   Training Loss: 0.8943
#   Validation Loss: 0.8955
#   Validation Accuracy: 0.5443
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 910 --------------------
# Epoch 910/10000:
#   Training Loss: 0.8940
#   Validation Loss: 0.8952
#   Validation Accuracy: 0.5444
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 911 --------------------
# Epoch 911/10000:
#   Training Loss: 0.8937
#   Validation Loss: 0.8949
#   Validation Accuracy: 0.5445
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 912 --------------------
# Epoch 912/10000:
#   Training Loss: 0.8934
#   Validation Loss: 0.8945
#   Validation Accuracy: 0.5443
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 913 --------------------
# Epoch 913/10000:
#   Training Loss: 0.8930
#   Validation Loss: 0.8942
#   Validation Accuracy: 0.5442
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 914 --------------------
# Epoch 914/10000:
#   Training Loss: 0.8927
#   Validation Loss: 0.8939
#   Validation Accuracy: 0.5442
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 915 --------------------
# Epoch 915/10000:
#   Training Loss: 0.8924
#   Validation Loss: 0.8936
#   Validation Accuracy: 0.5442
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 916 --------------------
# Epoch 916/10000:
#   Training Loss: 0.8920
#   Validation Loss: 0.8932
#   Validation Accuracy: 0.5442
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 917 --------------------
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7140e8b71a50>>
# Traceback (most recent call last):
#   File "/home/maichi/anaconda3/envs/env_aidream_registration/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# Epoch 917/10000:
#   Training Loss: 0.8917
#   Validation Loss: 0.8929
#   Validation Accuracy: 0.5445
#   GPU Memory Allocated: 0.02 GB
#   GPU Memory Reserved: 0.05 GB
# -------------------- Epoch 918 --------------------
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7140e8b71a50>>
# Traceback (most recent call last):
#   File "/home/maichi/anaconda3/envs/env_aidream_registration/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 9
#       7 model.train()
#       8 running_loss = 0.0
# ----> 9 for X_batch, y_batch in train_loader:
#      10     optimizer.zero_grad()           # Zero gradients
#      11     outputs = model(X_batch)        # Forward pass
#
# File ~/anaconda3/envs/env_aidream_registration/lib/python3.11/site-packages/torch/utils/data/dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File ~/anaconda3/envs/env_aidream_registration/lib/python3.11/site-packages/torch/utils/data/dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/anaconda3/envs/env_aidream_registration/lib/python3.11/site-packages/torch/utils/data/_utils/fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# File ~/anaconda3/envs/env_aidream_registration/lib/python3.11/site-packages/torch/utils/data/_utils/collate.py:398, in default_collate(batch)
#     337 def default_collate(batch):
#     338     r"""
#     339     Take in a batch of data and put the elements within the batch into a tensor with an additional outer dimension - batch size.
#     340
#    (...)
#     396         >>> default_collate(batch)  # Handle `CustomType` automatically
#     397     """
# --> 398     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File ~/anaconda3/envs/env_aidream_registration/lib/python3.11/site-packages/torch/utils/data/_utils/collate.py:211, in collate(batch, collate_fn_map)
#     208 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     210 if isinstance(elem, tuple):
# --> 211     return [
#     212         collate(samples, collate_fn_map=collate_fn_map)
#     213         for samples in transposed
#     214     ]  # Backwards compatibility.
#     215 else:
#     216     try:
#
# File ~/anaconda3/envs/env_aidream_registration/lib/python3.11/site-packages/torch/utils/data/_utils/collate.py:212, in <listcomp>(.0)
#     208 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     210 if isinstance(elem, tuple):
#     211     return [
# --> 212         collate(samples, collate_fn_map=collate_fn_map)
#     213         for samples in transposed
#     214     ]  # Backwards compatibility.
#     215 else:
#     216     try:
#
# File ~/anaconda3/envs/env_aidream_registration/lib/python3.11/site-packages/torch/utils/data/_utils/collate.py:155, in collate(batch, collate_fn_map)
#     153 if collate_fn_map is not None:
#     154     if elem_type in collate_fn_map:
# --> 155         return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     157     for collate_type in collate_fn_map:
#     158         if isinstance(elem, collate_type):
#
# File ~/anaconda3/envs/env_aidream_registration/lib/python3.11/site-packages/torch/utils/data/_utils/collate.py:272, in collate_tensor_fn(batch, collate_fn_map)
#     270     storage = elem._typed_storage()._new_shared(numel, device=elem.device)
#     271     out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 272 return torch.stack(batch, 0, out=out)
#
# KeyboardInterrupt:

# %%
X_test_tensor = torch.tensor(X_pred, dtype=torch.float32).to(device)

# %%
# Assuming `X_test_tensor` is the test data tensor
model.eval()  # Set the model to evaluation mode

# Perform predictions
with torch.no_grad():
    outputs = model(X_test_tensor)  # Raw model outputs (logits)
    predictions = outputs.argmax(dim=1)  # Predicted class labels

# Convert predictions to NumPy if needed
predictions_np = predictions.cpu().numpy() + 1

# %%
ants_prediction = ants.from_numpy(np.zeros(mask_ventricles_neighbors.shape), origin=mask_ventricles_neighbors.origin, spacing=mask_ventricles_neighbors.spacing, direction=mask_ventricles_neighbors.direction)

ants_prediction[pred_idx[0], pred_idx[1], pred_idx[2]] = predictions_np
ants_prediction[mask_ventricles == 1] = 1

# %%
ants_prediction.to_file(str(constants.DIR_DATA / "hammersmith" / "custom" / "ventricles_prediction.nii.gz"))
